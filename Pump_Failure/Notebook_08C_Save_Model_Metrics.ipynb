# %% [markdown]
# # Save Model Metrics and Feature Importance CSVs

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# ## RUL Metrics CSV

# %%
# Assumes mae, rmse, r2 already calculated
metrics_df = pd.DataFrame({
    'Metric':['MAE','RMSE','R2'],
    'Value':[mae, rmse, r2]
})
metrics_df.to_csv('pump_rul_metrics.csv', index=False)
metrics_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Assumes mae, rmse, r2 already calculated
#       2 metrics_df = pd.DataFrame({
#       3     'Metric':['MAE','RMSE','R2'],
# ----> 4     'Value':[mae, rmse, r2]
#       5 })
#       6 metrics_df.to_csv('pump_rul_metrics.csv', index=False)
#       7 metrics_df
#
# NameError: name 'mae' is not defined

# %% [markdown]
# ## Failure Probability Metrics CSV

# %%
# Assumes y_test and pred from failure probability model
accuracy = accuracy_score(y_test, pred)
precision = precision_score(y_test, pred)
recall = recall_score(y_test, pred)
f1 = f1_score(y_test, pred)

failure_metrics = pd.DataFrame({
    'Metric':['Accuracy','Precision','Recall','F1 Score'],
    'Value':[accuracy, precision, recall, f1]
})

failure_metrics.to_csv('pump_failure_probability_metrics.csv', index=False)
failure_metrics

# %% [markdown]
# ## Failure Mode Metrics CSV

# %%
# Assumes y_test and pred from failure mode model
mode_accuracy = accuracy_score(y_test, pred)

mode_metrics = pd.DataFrame({
    'Metric':['Accuracy'],
    'Value':[mode_accuracy]
})

mode_metrics.to_csv('pump_failure_mode_metrics.csv', index=False)
mode_metrics

# %% [markdown]
# ## Feature Importance CSV

# %%
# Assumes FEATURES and rul_model exist
feature_importance = pd.DataFrame({
    'Feature': FEATURES,
    'Importance': rul_model.feature_importances_
})

feature_importance = feature_importance.sort_values('Importance', ascending=False)
feature_importance.to_csv('pump_rul_feature_importance.csv', index=False)
feature_importance.head()

# %% [markdown]
# ## Master Metrics CSV

# %%
all_metrics = pd.concat([
    metrics_df.assign(Model='RUL'),
    failure_metrics.assign(Model='Failure Probability'),
    mode_metrics.assign(Model='Failure Mode')
])

all_metrics.to_csv('pump_model_metrics.csv', index=False)
all_metrics
